# %% [markdown]
# # CS 534 - Machine Learning
#
# # PS1
#
# # Name: Mostofa Najmus Sakib
# - St. Id: 114102108
#
# ## Collaborator: None

# %% [markdown]
# # Question 1 (10 pts) (Scikit Allowed)
#
# #### Create a script that:
#
# 1. Load the iris data.
# 2. Scale the independent features.
# 3. Compute the correlation coefficients and covariance among all the pair of independent features.
# 4. Compute the PCA and show the principal components (their coefficients).
# 5. Compute the correlation coefficient between each original feature and the new features generated by the PCA.

# %% [markdown]
# ### 1.1 Loading the Iris data

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.decomposition import PCA
import numpy as np
import math

# %%
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
data.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

data.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### 1.2 Scaling the independent features

# %%
dataWithoutClass = data.drop(columns=['class'])
dataWithoutClassScaled = preprocessing.scale(dataWithoutClass)
dataWithoutClassScaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
dataWithoutClassScaledDF = pd.DataFrame({'sepal_length_scaled': dataWithoutClassScaled[:, 0], 'sepal_width_scaled': dataWithoutClassScaled[:, 1], 'petal_length_scaled': dataWithoutClassScaled[:, 2], 'petal_width_scaled': dataWithoutClassScaled[:, 3]})
dataWithoutClassScaledDF.head()
# Out:
#    sepal_length_scaled  ...  petal_width_scaled
# 0            -0.900681  ...           -1.312977
# 1            -1.143017  ...           -1.312977
# 2            -1.385353  ...           -1.312977
# 3            -1.506521  ...           -1.312977
# 4            -1.021849  ...           -1.312977
#
# [5 rows x 4 columns]

# %% [markdown]
# ### 1.3 Compute the correlation coefficients and covariance among all the pair of independent features

# %%
corr = dataWithoutClassScaledDF.corr()
corr
# Out:
#                      sepal_length_scaled  ...  petal_width_scaled
# sepal_length_scaled             1.000000  ...            0.817954
# sepal_width_scaled             -0.109369  ...           -0.356544
# petal_length_scaled             0.871754  ...            0.962757
# petal_width_scaled              0.817954  ...            1.000000
#
# [4 rows x 4 columns]

# %%
cov = dataWithoutClassScaledDF.cov()
cov
# Out:
#                      sepal_length_scaled  ...  petal_width_scaled
# sepal_length_scaled             1.006711  ...            0.823443
# sepal_width_scaled             -0.110103  ...           -0.358937
# petal_length_scaled             0.877605  ...            0.969219
# petal_width_scaled              0.823443  ...            1.006711
#
# [4 rows x 4 columns]

# %% [markdown]
# ### 1.4 Compute the PCA and show the principal components (their coefficients)

# %%
pca = PCA(4)

# %%
principalComponents = pca.fit_transform(dataWithoutClassScaledDF)

# %%
principalComponentsDF = pd.DataFrame(principalComponents)
principalComponentsDF.columns = ['1', '2', '3', '4']
principalComponentsDF.head()
# Out:
#           1         2         3         4
# 0 -2.264542  0.505704 -0.121943 -0.023073
# 1 -2.086426 -0.655405 -0.227251 -0.103208
# 2 -2.367950 -0.318477  0.051480 -0.027825
# 3 -2.304197 -0.575368  0.098860  0.066311
# 4 -2.388777  0.674767  0.021428  0.037397

# %%
pca.components_  ##principal components (their coefficients)
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105],
#        [ 0.37231836,  0.92555649,  0.02109478,  0.06541577],
#        [-0.72101681,  0.24203288,  0.14089226,  0.6338014 ],
#        [-0.26199559,  0.12413481,  0.80115427, -0.52354627]])

# %% [markdown]
# ### 1.5 Compute the correlation coefficient between each original feature and the new features generated by the PCA.

# %% [markdown]
# Let's look at the correlation of the new features generated by the PCA:

# %%
principalComponentsDF.corr()
# Out:
#               1             2             3             4
# 1  1.000000e+00  5.988877e-17 -7.006857e-17 -3.550868e-17
# 2  5.988877e-17  1.000000e+00 -6.936964e-18 -9.052372e-17
# 3 -7.006857e-17 -6.936964e-18  1.000000e+00  1.074519e-16
# 4 -3.550868e-17 -9.052372e-17  1.074519e-16  1.000000e+00

# %% [markdown]
# Correlation between original features:

# %%
dataWithoutClass.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# Finally correlation coefficient between each original feature and the new features

# %%
totalDataFrame = pd.merge(data, principalComponentsDF, left_index=True, right_index=True)
totalDataFrame = totalDataFrame.drop(columns=['class'])
totalDataFrame.head()
# Out:
#    sepal length  sepal width  petal length  ...         2         3         4
# 0           5.1          3.5           1.4  ...  0.505704 -0.121943 -0.023073
# 1           4.9          3.0           1.4  ... -0.655405 -0.227251 -0.103208
# 2           4.7          3.2           1.3  ... -0.318477  0.051480 -0.027825
# 3           4.6          3.1           1.5  ... -0.575368  0.098860  0.066311
# 4           5.0          3.6           1.4  ...  0.674767  0.021428  0.037397
#
# [5 rows x 8 columns]

# %%
featureOne = totalDataFrame[['sepal length', '1', '2', '3', '4']].copy()
featureOne.corr()
# Out:
#               sepal length             1  ...             3             4
# sepal length      1.000000  8.912245e-01  ... -2.767740e-01 -3.761047e-02
# 1                 0.891224  1.000000e+00  ... -7.006857e-17 -3.550868e-17
# 2                 0.357352  5.988877e-17  ... -6.936964e-18 -9.052372e-17
# 3                -0.276774 -7.006857e-17  ...  1.000000e+00  1.074519e-16
# 4                -0.037610 -3.550868e-17  ...  1.074519e-16  1.000000e+00
#
# [5 rows x 5 columns]

# %%
featureTwo = totalDataFrame[['sepal width', '1', '2', '3', '4']].copy()
featureTwo.corr()
# Out:
#              sepal width             1  ...             3             4
# sepal width     1.000000 -4.493130e-01  ...  9.290825e-02  1.782003e-02
# 1              -0.449313  1.000000e+00  ... -7.006857e-17 -3.550868e-17
# 2               0.888351  5.988877e-17  ... -6.936964e-18 -9.052372e-17
# 3               0.092908 -7.006857e-17  ...  1.000000e+00  1.074519e-16
# 4               0.017820 -3.550868e-17  ...  1.074519e-16  1.000000e+00
#
# [5 rows x 5 columns]

# %%
featureThree = totalDataFrame[['petal length', '1', '2', '3', '4']].copy()
featureThree.corr()
# Out:
#               petal length             1  ...             3             4
# petal length      1.000000  9.916844e-01  ...  5.408378e-02  1.150088e-01
# 1                 0.991684  1.000000e+00  ... -7.006857e-17 -3.550868e-17
# 2                 0.020247  5.988877e-17  ... -6.936964e-18 -9.052372e-17
# 3                 0.054084 -7.006857e-17  ...  1.000000e+00  1.074519e-16
# 4                 0.115009 -3.550868e-17  ...  1.074519e-16  1.000000e+00
#
# [5 rows x 5 columns]

# %%
featureFour = totalDataFrame[['petal width', '1', '2', '3', '4']].copy()
featureFour.corr()
# Out:
#              petal width             1  ...             3             4
# petal width     1.000000  9.649958e-01  ...  2.432950e-01 -7.515708e-02
# 1               0.964996  1.000000e+00  ... -7.006857e-17 -3.550868e-17
# 2               0.062786  5.988877e-17  ... -6.936964e-18 -9.052372e-17
# 3               0.243295 -7.006857e-17  ...  1.000000e+00  1.074519e-16
# 4              -0.075157 -3.550868e-17  ...  1.074519e-16  1.000000e+00
#
# [5 rows x 5 columns]

# %% [markdown]
# # Question 2 (5 pts + (5 pts Extra))
#
# 1. What you can observe by comparing the results in subquestions  4 and 5 of Question1?
# 2. Can you define any property?
# 3. If there is any property are you able to formally prove it? (5 extra pts)

# %% [markdown]
# ## 2.1 What you can observe by comparing the results in subquestions 4 and 5 of Question1?

# %% [markdown]
# We can observe that each of the new features except one has at least one very high coefficient. Only one of them has three. We can also observe that the original features are correlated to each other. For example we can see that there are correlations between sepal length and petal length. But the new features from pca are independent. In other words, the new feautres are uncorrelated. In general variability of the independent variables were captured by the PCA components

# %% [markdown]
# ## 2.2 Can you define any property?

# %% [markdown]
# The features from PCA are orthogonal and independent. Calculated variance of the principal component has orthogonal parts of the varaince of the primary variables available. Principal component has helped here to reduce the dimensionality of the datasets. The prinicipal components derived from the PCA is generally the sum of the independent random variables whereas variancce is equal to the sum of the variances
#
# Other terminologies associated with PCA is "Eigen vector" and "Eigen value". In linear algebra, an eigenvector or characteristic vector of a linear transformation is a nonzero vector that changes by a scalar factor when that linear transformation is applied to it. The corresponding eigenvalue is the factor by which the eigenvector is scaled.

# %% [markdown]
# # Question 3 (10 pts) (Scikit NOT Allowed)
#
# Write a code in pure python, to create a decision tree (please show the results).
#  1. Create a toy example to run and test your code.
#  2. Provide simple explanation for your algorithm.
#  3. In input, you should provide the independent features and the dependent feature (the class/label) separately.
#  4. Also implement the gini index and the entropy gain ratio in your toy example.
#
# Notes: You can assume that the dependent and independent features are binary and may use numpy and scipy.
# You can read the code available online, but you cannot plagiarize it.

# %% [markdown]
# #### ***I have tried to explain each step  of the algorithm and results in the associated steps***

# %% [markdown]
# ## Pure python implementation of a decision tree with requirements described above:

# %% [markdown]
# ### To implement a decision tree, first we need the Attribute Selection Measures

# %% [markdown]
# The following function is written separetely and is used by the fuctions which retrieves the gini index and entropy gain ratio. This function basically checks whether a feature name is valid

# %%
def isFeatureValid(dataset, feature):
    allFeatures = dataset.columns
    result = False
    for i in range(0, len(dataset.columns)):
        if allFeatures[i] == feature:
            result = True
            break
    return result

# %% [markdown]
# #### The following two functions are used to calculate the Gini Index and Gini Split

# %%
#Function to Calculate Gini index
def GiniIndex(dataset):
    outputSeries = dataset['output']
    uniqueOutputKeys = outputSeries.value_counts().keys().tolist()
    uniqueOutputValues = outputSeries.value_counts().tolist()
    result = 1    # initially the result is 1 because of the formula: GINI(T) = 1 - Σ [p(j|t)]^2
    
    for i in range(0, len(uniqueOutputKeys)):
        prob = uniqueOutputValues[i]/len(dataset['output'])
        result = result - (prob * prob)     #GINI(T) = 1 - Σ [p(j|t)]^2
    return result
    
#function to calculate the Gini Split
def GiniSplit(dataset, output, feature):
    if isFeatureValid(dataset, feature) == False:
        print("invalid column name!")
        return
    
    currentFeatureSeries = dataset[feature]    #list of all the features
    
    valueCounts = currentFeatureSeries.value_counts()
    valueCountsKeys = currentFeatureSeries.value_counts().keys().tolist()
    valueCountsValues = currentFeatureSeries.value_counts().tolist()
    
    fullDataToCheck = pd.DataFrame({'current_feature': currentFeatureSeries, 'output': output})
    result = 0
    for i in range(0, len(valueCountsKeys)):    #this loop sums all gini indexes by the formula GINIsplit = Σ (ni/n)*GINI(i)
        partitionedData = fullDataToCheck[fullDataToCheck['current_feature'] == valueCountsKeys[i]]
        gIndex = GiniIndex(partitionedData)
        
        result = result + (gIndex * len(partitionedData) / len(fullDataToCheck['output']))
    
    return result

# %% [markdown]
# The following two functions are used to calculate entropy and entropy gain ratio

# %%
# function to calculate entropy
def Entropy(dataset):    #this function calculates the entropy using the formula Entropy(T) = -Σ P(j|t) * log(P(j|t))
    outputSeries = dataset['output']
    uniqueOutputKeys = outputSeries.value_counts().keys().tolist()
    uniqueOutputValues = outputSeries.value_counts().tolist()
    result = 0
    
    for i in range(0, len(uniqueOutputKeys)):
        lgProb = uniqueOutputValues[i]/len(dataset['output'])
        result = result + (lgProb * math.log(lgProb, 2))    #P(j|t) * log(P(j|t))
    result = -1 * result    #at the end of the loop we need to negate the result because of the formula
    return result

#function to calculate entropy gain ratio
def EntropyGainRatio(dataset, output, feature):
    
    fullData = dataset
    fullData['output'] = output
    parentE = Entropy(fullData)    # parent entropy
    
    
    ## now find the entropy for all the childs that will be produced from using this feature
    if isFeatureValid(dataset, feature) == False:
        print("invalid column name!")
        return
    
    currentFeatureSeries = dataset[feature]
    valueCounts = currentFeatureSeries.value_counts()
    valueCountsKeys = currentFeatureSeries.value_counts().keys().tolist()
    valueCountsValues = currentFeatureSeries.value_counts().tolist()
    
    fullDataToCheck = pd.DataFrame({'current_feature': currentFeatureSeries, 'output': output})
    
    eGain = 0   #this variable stores the information gain, GAINsplit = Entropy(P) - Σ ((ni/n)*Entropy(i))
    splitI = 0  # this variable stores the splitInfo, splitInfo = -Σ ((ni/n)*log(ni/n))
    for i in range(0, len(valueCountsKeys)):    #this loop uses the function Entropy(dataset), and calculates eGain and SplitI
        partitionedData = fullDataToCheck[fullDataToCheck['current_feature'] == valueCountsKeys[i]]
        
        entropy = Entropy(partitionedData)
        entropyM = entropy * len(partitionedData) / len(fullDataToCheck)
        eGain = eGain + entropyM
        
        nByN = len(partitionedData) / len(fullDataToCheck)
        splitI = splitI + nByN * ((math.log(nByN, 2)))
        
    
    eGain = parentE - eGain # because of the formula GAINsplit = Entropy(P) - Σ ((ni/n)*Entropy(i))
    splitI = splitI * (-1.0) #GainRatio = GAINsplit/SplitInfo
    
    
    if splitI == 0.0:    #floating point precision handling
        splitI = 0.0000001
    gRatio = eGain / splitI
    
    return gRatio

# %% [markdown]
# #### The following function is the raw python implementation of decision tree

# %% [markdown]
# Since we can assume that the features we deal with will be binary, I have used a binary tree structure to store the output of the Decision Tree Generation function. The parameters treeTracker and treeTrackerNextCheck holds the tree information into 2 arrays that is generated from the function. The root of the binary tree starts from zero. Because of that, in the next couple of cells, the function is initially called with root value 0.

# %%
# the decision tree generator function
#treeTracker holds which feature to check at each iteration
#treeTrackerNextCheck holds the indices values and which direction to go for which feature value
def GenerateDecisionTree(Dataset, output, AttributeSelectionMeasures, treeTracker, treeTrackerNextCheck, root):
    
    if len(Dataset) == 0:
        return
    
    bestFeature = None
    valueForBestFeature = -1    # this variables hold the best feature to split with after checking all the features
    allFeatures = Dataset.columns  #list of all features
    gain = None  #this variable holds the gain value from the particular Attribute Selection Measure for the best feature
    
    for i in range(0, len(allFeatures)):    # this loop uses the Attribute Selection Measure to get the best feature and calculates the gain
        if AttributeSelectionMeasures == "Gini Index":    #if AttributeSelectionMeasure is gini index we call the gini index related function
            gain = GiniSplit(Dataset, output, allFeatures[i])
        elif AttributeSelectionMeasures == "Entropy Gain Ratio":   #if AttributeSelectionMeasure is gain ratio, we call the related function
            gain = EntropyGainRatio(Dataset, output, allFeatures[i])
        else:
            print("No such measure found named " + str(AttributeSelectionMeasures))  #otherwise AttributeSelectionMeasure is invalid
            return
        if gain > valueForBestFeature:
            valueForBestFeature = gain
            bestFeature = allFeatures[i]
    
    
    bestFeatureColumn = Dataset[bestFeature]
    uniqueValues = bestFeatureColumn.unique()
    
    combinedData = Dataset
    combinedData['output'] = output
    for i in range(0, len(uniqueValues)):    # this loop calculates the next node of the tree, here the function recursively calls itself to go deeper into the tree
        separatedData = combinedData[combinedData[bestFeature] == uniqueValues[i]]
        if len(separatedData) == 0:    #we reached an end
            treeTracker[root] = bestFeature
            treeTracker[root*2+1] = "end"
            treeTracker[root*2+2] = "end"
            continue
        if len(separatedData) == len(Dataset):    #we reached an end
            treeTracker[root] = bestFeature
            treeTracker[root*2+1] = "end"
            treeTracker[root*2+2] = "end"
            treeTrackerNextCheck[root*2+1] = separatedData.iloc[0]['output']#uniqueValues[i]
            treeTrackerNextCheck[root*2+2] = separatedData.iloc[0]['output']#uniqueValues[i]
            continue
        if i == 0:
            treeTracker[root] = bestFeature
            treeTrackerNextCheck[root*2+1] = uniqueValues[i]
            output = separatedData['output']
            separatedData = separatedData.drop('output', 1)
            GenerateDecisionTree(separatedData, output, AttributeSelectionMeasures, treeTracker, treeTrackerNextCheck, 2*root+1)
        else:
            treeTracker[root] = bestFeature
            treeTrackerNextCheck[root*2+2] = uniqueValues[i]
            output = separatedData['output']
            separatedData = separatedData.drop('output', 1)
            GenerateDecisionTree(separatedData, output, AttributeSelectionMeasures, treeTracker, treeTrackerNextCheck, 2*root+2)
        
        
    return

# this is the actual function that we call go get the decision tree, this one calls the function above to generate the tree
#you need to call the function using the dataframe containing the dependant variables(Dataset), the output, and the Attribute Selection Measure 
#treeTracker holds which feature to check at each iteration
#treeTrackerNextCheck holds the indices values and which direction to go for which feature value
def DecisionTree(Dataset, output, AttributeSelectionMeasures):
    treeTracker = [None] * 100000000
    treeTrackerNextCheck = [None] * 100000000
    GenerateDecisionTree(Dataset, output, AttributeSelectionMeasures, treeTracker, treeTrackerNextCheck, 0)  # 0 here is the root
    return treeTracker, treeTrackerNextCheck

# %% [markdown]
# #### The following functions are used to test the decision tree on test data

# %%
# checks the tree for only one row/data point
def GetDecisionTreeResult(treeTracker, treeTrackerNextCheck, oneDataPoint):
    root = 0
    while treeTracker[root] != "end":
        currentFeatureToTest = treeTracker[root]
        thatFeatureResult = oneDataPoint[currentFeatureToTest]
        
        if thatFeatureResult == treeTrackerNextCheck[root*2 + 1]:
            root = root*2 + 1
        elif thatFeatureResult == treeTrackerNextCheck[root*2 + 2]:
            root = root*2 + 2
        elif treeTracker[root*2+1] == "end" and treeTracker[root*2+2] == "end":
            break;
        
    return treeTrackerNextCheck[root*2+1]

#this function uses the function above in a loop to get the prediction for all rows in a dataframe
def TestDecisionTree(treeTracker, treeTrackerNextCheck, data):
    prediction = []#pd.Series()
    for i in range(0, len(data)):
        temp = data.iloc[i]
        tempResult = GetDecisionTreeResult(treeTracker, treeTrackerNextCheck, temp)
        prediction.append(tempResult)# = prediction.set_value(i, tempResult)
    
    return prediction#.tolist()

# %% [markdown]
# ## Toy example to run and test above code

# %%
import warnings
warnings.simplefilter('ignore')
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()

# %%
sampleData = pd.read_excel("ToyExample.xlsx");
sampleData.head()
# Out:
#   Body Temperature Gives Birth Aquatic Creature  ... Has Legs Hibernates      output
# 0             warm         Yes               No  ...      Yes         No      mammal
# 1             cold          No               No  ...       No        Yes  not mammal
# 2             cold          No              Yes  ...       No         No  not mammal
# 3             warm         Yes              Yes  ...       No         No      mammal
# 4             cold          No               No  ...      Yes        Yes  not mammal
#
# [5 rows x 7 columns]

# %% [markdown]
# Splitting the data into train and test

# %%
trainSampleData = sampleData.head(12)
trainSampleData.head()
# Out:
#   Body Temperature Gives Birth Aquatic Creature  ... Has Legs Hibernates      output
# 0             warm         Yes               No  ...      Yes         No      mammal
# 1             cold          No               No  ...       No        Yes  not mammal
# 2             cold          No              Yes  ...       No         No  not mammal
# 3             warm         Yes              Yes  ...       No         No      mammal
# 4             cold          No               No  ...      Yes        Yes  not mammal
#
# [5 rows x 7 columns]

# %%
testSampleData = sampleData.tail(3)
testSampleData.head()
# Out:
#    Body Temperature Gives Birth  ... Hibernates      output
# 12             warm         Yes  ...        Yes      mammal
# 13             cold          No  ...         No  not mammal
# 14             cold          No  ...        Yes  not mammal
#
# [3 rows x 7 columns]

# %% [markdown]
# #### Let's get the decision tree, first we are going to use "Entropy Gain Ratio"

# %%
#first separate the independant and dependant variables
trainDataOnlyDependantFeatures = trainSampleData[['Body Temperature', 'Gives Birth', 'Aquatic Creature', 'Aerial Creature', 'Has Legs', 'Hibernates']]
trainDataOnlyOutput = trainSampleData['output']

#now get the tree(arrays)
res1, res2 = DecisionTree(trainDataOnlyDependantFeatures, trainDataOnlyOutput, "Entropy Gain Ratio")

#the res1 and res2 variable holds the tree
#res1 holds which feature to check at each iteration
#res2 holds the indices values and which direction to go for which feature value

# %%
testSampleData
# Out:
#    Body Temperature Gives Birth  ... Hibernates      output
# 12             warm         Yes  ...        Yes      mammal
# 13             cold          No  ...         No  not mammal
# 14             cold          No  ...        Yes  not mammal
#
# [3 rows x 7 columns]

# %% [markdown]
# #### Now we can test on the testSampleData as following:

# %%
prediction = TestDecisionTree(res1, res2, testSampleData)

# %%
prediction
# Out:
# ['mammal', 'not mammal', 'not mammal']

# %% [markdown]
# Let's put it with the dataframe to see actually how the prediction looks like:

# %%
testSampleData.insert(len(testSampleData.columns), "prediction", prediction, True)
testSampleData
# Out:
#    Body Temperature Gives Birth  ...      output  prediction
# 12             warm         Yes  ...      mammal      mammal
# 13             cold          No  ...  not mammal  not mammal
# 14             cold          No  ...  not mammal  not mammal
#
# [3 rows x 8 columns]

# %% [markdown]
# ### let's  try same thing with gini index

# %%
trainDataOnlyDependantFeatures = trainSampleData[['Body Temperature', 'Gives Birth', 'Aquatic Creature', 'Aerial Creature', 'Has Legs', 'Hibernates']]
trainDataOnlyOutput = trainSampleData['output']

ress1, ress2 = DecisionTree(trainDataOnlyDependantFeatures, trainDataOnlyOutput, "Gini Index")

# %%
testSampleData = sampleData.tail(3)
testSampleData
# Out:
#    Body Temperature Gives Birth  ... Hibernates      output
# 12             warm         Yes  ...        Yes      mammal
# 13             cold          No  ...         No  not mammal
# 14             cold          No  ...        Yes  not mammal
#
# [3 rows x 7 columns]

# %%
prediction = TestDecisionTree(ress1, ress2, testSampleData)
prediction
# Out:
# ['not mammal', 'not mammal', 'not mammal']

# %%
testSampleData.insert(len(testSampleData.columns), "prediction", prediction, True)
testSampleData
# Out:
#    Body Temperature Gives Birth  ...      output  prediction
# 12             warm         Yes  ...      mammal  not mammal
# 13             cold          No  ...  not mammal  not mammal
# 14             cold          No  ...  not mammal  not mammal
#
# [3 rows x 8 columns]
